# %%
# save depreciation data as individual files

import pandas as pd
import numpy as np
from statsmodels.nonparametric.smoothers_lowess import lowess
import joblib
import os

# Load data
df_2024 = pd.read_csv('../data/processed/2024_turkey_car_market_ML.csv')

# Identify all Make-Model combinations and count their occurrences
make_model_counts = df_2024.groupby(['Make', 'Model']).size().reset_index(name='counts')

# Filter out Make-Model combinations with fewer than 20 entries
make_model_filtered = make_model_counts[make_model_counts['counts'] >= 20]

# Sort the Make-Model combinations by total counts in descending order
make_model_filtered = make_model_filtered.sort_values(by='counts', ascending=False)

# Prepare a dictionary to store results
depreciation_data = {}

# Process each Make-Model combination
for _, row in make_model_filtered.iterrows():
    make, model = row['Make'], row['Model']
    print(f"Processing {make} {model}")
    
    try:
        df_make_model = df_2024[(df_2024['Make'] == make) & (df_2024['Model'] == model)]
        
        # Filter based on kilometers
        median_km = df_make_model['Kilometers (km)'].median()
        df_make_model = df_make_model[df_make_model['Kilometers (km)'] <= median_km * 1.3]
        
        # Filter out cars older than 15 years
        df_make_model = df_make_model[df_make_model['Car Age (Years)'] <= 15]

        # Ensure there are still rows left after filtering
        if df_make_model.empty:
            print(f"No data available for {make} {model} after applying filters.")
            continue

        # Group by "Car Age (Years)" and calculate the median price for each age
        median_prices = df_make_model.groupby('Car Age (Years)')['Price USD'].median().reset_index()

        # Ensure we have a complete range of years
        min_year = int(median_prices['Car Age (Years)'].min())
        max_year = int(median_prices['Car Age (Years)'].max())
        all_years = pd.DataFrame({'Car Age (Years)': range(min_year, max_year + 1)})
        median_prices = pd.merge(all_years, median_prices, on='Car Age (Years)', how='left')
        median_prices['Price USD'].interpolate(method='linear', inplace=True)

        # Add the count of cars used to calculate the median price for each year
        car_counts = df_make_model.groupby('Car Age (Years)').size().reindex(all_years['Car Age (Years)'], fill_value=0).reset_index(name='Car Count')
        median_prices = pd.merge(median_prices, car_counts, on='Car Age (Years)', how='left')

        # Filter out entries with fewer than 5 cars
        median_prices = median_prices[median_prices['Car Count'] >= 5]

        if median_prices.empty:
            print(f"No data available for {make} {model} after filtering for car count.")
            continue

        # Apply rolling average for smoothing
        median_prices['Smoothed Price'] = median_prices['Price USD'].rolling(window=3, center=True).mean()

        # Apply LOWESS for further smoothing
        lowess_smoothed = lowess(median_prices['Price USD'], median_prices['Car Age (Years)'], frac=0.2)
        median_prices['LOWESS Price'] = lowess_smoothed[:, 1]

        # Calculate the percentage loss for each year-to-year step
        median_prices['Percentage Loss'] = median_prices['LOWESS Price'].pct_change() * 100

        # Store the median prices in the results dictionary
        depreciation_data[(make, model)] = median_prices

        # Save the data
        file_path = f"../data/models/depreciation_data/{make}_{model}_depreciation.pkl"
        if not os.path.exists(file_path):
            os.makedirs(file_path)
        joblib.dump(median_prices, file_path)
        print(f"Depreciation data saved for {make} {model}")

    except Exception as e:
        print(f"Error processing {make} {model}: {e}")
        continue

# Prepare and save make-level depreciation data
make_counts = df_2024.groupby('Make').size().reset_index(name='counts')
make_filtered = make_counts[make_counts['counts'] >= 20]

for _, row in make_filtered.iterrows():
    make = row['Make']
    print(f"Processing {make}")
    
    try:
        df_make = df_2024[df_2024['Make'] == make]
        
        # Filter based on kilometers
        median_km = df_make['Kilometers (km)'].median()
        df_make = df_make[df_make['Kilometers (km)'] <= median_km * 1.3]
        
        # Filter out cars older than 15 years
        df_make = df_make[df_make['Car Age (Years)'] <= 15]

        # Ensure there are still rows left after filtering
        if df_make.empty:
            print(f"No data available for {make} after applying filters.")
            continue

        # Group by "Car Age (Years)" and calculate the median price for each age
        median_prices = df_make.groupby('Car Age (Years)')['Price USD'].median().reset_index()

        # Ensure we have a complete range of years
        min_year = int(median_prices['Car Age (Years)'].min())
        max_year = int(median_prices['Car Age (Years)'].max())
        all_years = pd.DataFrame({'Car Age (Years)': range(min_year, max_year + 1)})
        median_prices = pd.merge(all_years, median_prices, on='Car Age (Years)', how='left')
        median_prices['Price USD'].interpolate(method='linear', inplace=True)

        # Add the count of cars used to calculate the median price for each year
        car_counts = df_make.groupby('Car Age (Years)').size().reindex(all_years['Car Age (Years)'], fill_value=0).reset_index(name='Car Count')
        median_prices = pd.merge(median_prices, car_counts, on='Car Age (Years)', how='left')

        # Filter out entries with fewer than 5 cars
        median_prices = median_prices[median_prices['Car Count'] >= 5]

        if median_prices.empty:
            print(f"No data available for {make} after filtering for car count.")
            continue

        # Apply rolling average for smoothing
        median_prices['Smoothed Price'] = median_prices['Price USD'].rolling(window=3, center=True).mean()

        # Apply LOWESS for further smoothing
        lowess_smoothed = lowess(median_prices['Price USD'], median_prices['Car Age (Years)'], frac=0.2)
        median_prices['LOWESS Price'] = lowess_smoothed[:, 1]

        # Calculate the percentage loss for each year-to-year step
        median_prices['Percentage Loss'] = median_prices['LOWESS Price'].pct_change() * 100

        # Store the make-level median prices in the results dictionary
        depreciation_data[make] = median_prices

        # Save the make-level data
        file_path = f"../data/models/depreciation_data/{make}_depreciation.pkl"
        joblib.dump(median_prices, file_path)
        print(f"Depreciation data saved for {make}")

    except Exception as e:
        print(f"Error processing {make}: {e}")
        continue

# Save the full depreciation data dictionary
joblib.dump(depreciation_data, "../data/models/depreciation_data/depreciation_data_full.pkl")
# Out:
# Processing Opel Corsa
# Depreciation data saved for Opel Corsa
# Processing Ford Focus
# Depreciation data saved for Ford Focus
# Processing Volkswagen Passat
# Depreciation data saved for Volkswagen Passat
# Processing Volkswagen Polo
# Depreciation data saved for Volkswagen Polo
# Processing Honda Civic
# Depreciation data saved for Honda Civic
# Processing Fiat Egea
# Depreciation data saved for Fiat Egea
# Processing Toyota Corolla
# Depreciation data saved for Toyota Corolla
# Processing Renault Clio
# Depreciation data saved for Renault Clio
# Processing Renault Megane
# Depreciation data saved for Renault Megane
# Processing Opel Astra
# Depreciation data saved for Opel Astra
# Processing Fiat Linea
# Depreciation data saved for Fiat Linea
# Processing Volkswagen Golf
# Depreciation data saved for Volkswagen Golf
# Processing Ford Fiesta
# Depreciation data saved for Ford Fiesta
# Processing Renault Symbol
# Depreciation data saved for Renault Symbol
# Processing Renault Fluence
# Depreciation data saved for Renault Fluence
# Processing Volkswagen Jetta
# Depreciation data saved for Volkswagen Jetta
# Processing BMW 3 Series
# Depreciation data saved for BMW 3 Series
# Processing Hyundai i20
# Depreciation data saved for Hyundai i20
# Processing Hyundai Accent
# No data available for Hyundai Accent after filtering for car count.
# Processing Opel Vectra
# No data available for Opel Vectra after filtering for car count.
# Processing Tofaş Şahin
# No data available for Tofaş Şahin after applying filters.
# Processing Fiat Palio
# Depreciation data saved for Fiat Palio
# Processing Fiat Punto
# Depreciation data saved for Fiat Punto
# Processing BMW 5 Series
# Depreciation data saved for BMW 5 Series
# Processing Tofaş Doğan
# No data available for Tofaş Doğan after applying filters.
# Processing Mercedes C
# Depreciation data saved for Mercedes C
# Processing Seat Leon
# Depreciation data saved for Seat Leon
# Processing Audi A3
# Depreciation data saved for Audi A3
# Processing Peugeot 206
# Depreciation data saved for Peugeot 206
# Processing Peugeot 307
# No data available for Peugeot 307 after applying filters.
# Processing Skoda Octavia
# Depreciation data saved for Skoda Octavia
# Processing Citroen C-Elysee
# Depreciation data saved for Citroen C-Elysee
# Processing Mercedes E
# Depreciation data saved for Mercedes E
# Processing Dacia Sandero
# Depreciation data saved for Dacia Sandero
# Processing Hyundai Accent Blue
# Depreciation data saved for Hyundai Accent Blue
# Processing Citroen C4
# Depreciation data saved for Citroen C4
# Processing Audi A4
# Depreciation data saved for Audi A4
# Processing Ford Mondeo
# Depreciation data saved for Ford Mondeo
# Processing Seat Ibiza
# Depreciation data saved for Seat Ibiza
# Processing Chevrolet Cruze
# Depreciation data saved for Chevrolet Cruze
# Processing Citroen C3
# Depreciation data saved for Citroen C3
# Processing Skoda SuperB
# Depreciation data saved for Skoda SuperB
# Processing Skoda Fabia
# Depreciation data saved for Skoda Fabia
# Processing Chevrolet Aveo
# Depreciation data saved for Chevrolet Aveo
# Processing BMW 1 Series
# Depreciation data saved for BMW 1 Series
# Processing Peugeot 301
# Depreciation data saved for Peugeot 301
# Processing Renault Laguna
# Depreciation data saved for Renault Laguna
# Processing Hyundai Accent Era
# Depreciation data saved for Hyundai Accent Era
# Processing Nissan Micra
# Depreciation data saved for Nissan Micra
# Processing Kia Rio
# Depreciation data saved for Kia Rio
# Processing Dacia Logan
# Depreciation data saved for Dacia Logan
# Processing Audi A6
# Depreciation data saved for Audi A6
# Processing Hyundai Getz
# Depreciation data saved for Hyundai Getz
# Processing Tofaş Kartal
# No data available for Tofaş Kartal after applying filters.
# Processing Peugeot 308
# Depreciation data saved for Peugeot 308
# Processing Toyota Auris
# Depreciation data saved for Toyota Auris
# Processing Volvo S40
# Depreciation data saved for Volvo S40
# Processing Peugeot 207
# Depreciation data saved for Peugeot 207
# Processing Citroen C5
# Depreciation data saved for Citroen C5
# Processing Volvo S60
# Depreciation data saved for Volvo S60
# Processing Toyota Yaris
# Depreciation data saved for Toyota Yaris
# Processing Kia Ceed
# Depreciation data saved for Kia Ceed
# Processing Seat Toledo
# Depreciation data saved for Seat Toledo
# Processing Seat Cordoba
# No data available for Seat Cordoba after filtering for car count.
# Processing Peugeot 208
# Depreciation data saved for Peugeot 208
# Processing Lada Samara
# No data available for Lada Samara after applying filters.
# Processing Mercedes A
# Depreciation data saved for Mercedes A
# Processing Chevrolet Kalos
# No data available for Chevrolet Kalos after applying filters.
# Processing Mercedes CLA
# Depreciation data saved for Mercedes CLA
# Processing Lada Vega
# No data available for Lada Vega after applying filters.
# Processing Fiat Albea
# Depreciation data saved for Fiat Albea
# Processing Mazda 3
# Depreciation data saved for Mazda 3
# Processing Honda Jazz
# Depreciation data saved for Honda Jazz
# Processing Chevrolet Lacetti
# Depreciation data saved for Chevrolet Lacetti
# Processing Kia Cerato
# Depreciation data saved for Kia Cerato
# Processing Honda City
# Depreciation data saved for Honda City
# Processing Hyundai Elantra
# Depreciation data saved for Hyundai Elantra
# Processing Nissan Primera
# No data available for Nissan Primera after applying filters.
# Processing Suzuki Swift
# Depreciation data saved for Suzuki Swift
# Processing Skoda Felicia
# No data available for Skoda Felicia after applying filters.
# Processing Skoda Rapid
# Depreciation data saved for Skoda Rapid
# Processing Audi A5
# Depreciation data saved for Audi A5
# Processing Hyundai i30
# Depreciation data saved for Hyundai i30
# Processing Dacia Lodgy
# Depreciation data saved for Dacia Lodgy
# Processing Mazda 323
# No data available for Mazda 323 after applying filters.
# Processing Peugeot 508
# Depreciation data saved for Peugeot 508
# Processing Skoda Favorit
# No data available for Skoda Favorit after applying filters.
# Processing Mitsubishi Lancer
# Depreciation data saved for Mitsubishi Lancer
# Processing Renault R 9
# No data available for Renault R 9 after applying filters.
# Processing MINI Cooper
# Depreciation data saved for MINI Cooper
# Processing Ford Escort
# No data available for Ford Escort after applying filters.
# Processing Kia Picanto
# Depreciation data saved for Kia Picanto
# Processing Peugeot 407
# No data available for Peugeot 407 after filtering for car count.
# Processing Fiat Uno
# No data available for Fiat Uno after applying filters.
# Processing Nissan Almera
# No data available for Nissan Almera after applying filters.
# Processing Toyota Avensis
# Depreciation data saved for Toyota Avensis
# Processing Citroen Xsara
# No data available for Citroen Xsara after applying filters.
# Processing Mercedes S
# Depreciation data saved for Mercedes S
# Processing Volkswagen Bora
# No data available for Volkswagen Bora after applying filters.
# Processing Alfa Romeo Giulietta
# Depreciation data saved for Alfa Romeo Giulietta
# Processing Mercedes B
# Depreciation data saved for Mercedes B
# Processing Peugeot 206+
# Depreciation data saved for Peugeot 206+
# Processing Honda Accord
# Depreciation data saved for Honda Accord
# Processing Nissan Note
# Depreciation data saved for Nissan Note
# Processing Mazda 626
# No data available for Mazda 626 after applying filters.
# Processing Fiat Tipo
# No data available for Fiat Tipo after applying filters.
# Processing Peugeot 306
# No data available for Peugeot 306 after applying filters.
# Processing Skoda Scala
# Depreciation data saved for Skoda Scala
# Processing Mercedes 200
# No data available for Mercedes 200 after filtering for car count.
# Processing Mitsubishi Carisma
# No data available for Mitsubishi Carisma after applying filters.
# Processing Citroen Saxo
# No data available for Citroen Saxo after applying filters.
# Processing Mitsubishi Colt
# Depreciation data saved for Mitsubishi Colt
# Processing Ford C-Max
# Depreciation data saved for Ford C-Max
# Processing Tofaş Murat
# No data available for Tofaş Murat after applying filters.
# Processing Renault R 12
# No data available for Renault R 12 after applying filters.
# Processing Fiat Tempra
# No data available for Fiat Tempra after applying filters.
# Processing Renault R 19
# No data available for Renault R 19 after applying filters.
# Processing Volvo S80
# Depreciation data saved for Volvo S80
# Processing Volvo V40
# Depreciation data saved for Volvo V40
# Processing Opel Insignia
# Depreciation data saved for Opel Insignia
# Processing Volkswagen VW CC
# Depreciation data saved for Volkswagen VW CC
# Processing Ford Fusion
# No data available for Ford Fusion after filtering for car count.
# Processing Citroen C4 Grand Picasso
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# Depreciation data saved for Citroen C4 Grand Picasso
# Processing Skoda Forman
# No data available for Skoda Forman after filtering for car count.
# Processing Peugeot 106
# No data available for Peugeot 106 after applying filters.
# Processing Alfa Romeo 156
# No data available for Alfa Romeo 156 after applying filters.
# Processing Hyundai i10
# Depreciation data saved for Hyundai i10
# Processing Fiat Marea
# No data available for Fiat Marea after applying filters.
# Processing Tofaş Serçe
# No data available for Tofaş Serçe after applying filters.
# Processing Fiat Fiorino
# Depreciation data saved for Fiat Fiorino
# Processing Kia Sephia
# No data available for Kia Sephia after applying filters.
# Processing Mercedes 190
# No data available for Mercedes 190 after applying filters.
# Processing Dacia Solenza
# No data available for Dacia Solenza after applying filters.
# Processing Alfa Romeo 147
# No data available for Alfa Romeo 147 after filtering for car count.
# Processing Fiat Siena
# No data available for Fiat Siena after applying filters.
# Processing Seat Altea
# Depreciation data saved for Seat Altea
# Processing Fiat 500
# Depreciation data saved for Fiat 500
# Processing Citroen C4 X
# Depreciation data saved for Citroen C4 X
# Processing Citroen C4 Picasso
# Depreciation data saved for Citroen C4 Picasso
# Processing Renault Taliant
# Depreciation data saved for Renault Taliant
# Processing Tata Indica
# No data available for Tata Indica after filtering for car count.
# Processing Subaru Impreza
# No data available for Subaru Impreza after filtering for car count.
# Processing Porsche Panamera
# Depreciation data saved for Porsche Panamera
# Processing Peugeot 406
# No data available for Peugeot 406 after applying filters.
# Processing Ford Taunus
# No data available for Ford Taunus after applying filters.
# Processing Fiat Doblo
# Depreciation data saved for Fiat Doblo
# Processing Hyundai i20 Troy
# Depreciation data saved for Hyundai i20 Troy
# Processing Ford Tourneo Courier
# Depreciation data saved for Ford Tourneo Courier
# Processing Chevrolet Spark
# Depreciation data saved for Chevrolet Spark
# Processing Volvo S90
# Depreciation data saved for Volvo S90
# Processing Tata Indigo
# Depreciation data saved for Tata Indigo
# Processing Suzuki SX4
# Depreciation data saved for Suzuki SX4
# Processing Citroen C3 Picasso
# Depreciation data saved for Citroen C3 Picasso
# Processing Toyota Verso
# Depreciation data saved for Toyota Verso
# Processing Tata Marina
# No data available for Tata Marina after filtering for car count.
# Processing Porsche 911
# Depreciation data saved for Porsche 911
# Processing Mercedes CLS
# No data available for Mercedes CLS after filtering for car count.
# Processing Mercedes CLK
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# No data available for Mercedes CLK after applying filters.
# Processing Mitsubishi Space Star
# Depreciation data saved for Mitsubishi Space Star
# Processing Suzuki Maruti
# No data available for Suzuki Maruti after applying filters.
# Processing Fiat Bravo
# Depreciation data saved for Fiat Bravo
# Processing Suzuki Alto
# Depreciation data saved for Suzuki Alto
# Processing Skoda Roomster
# Depreciation data saved for Skoda Roomster
# Processing Renault Scenic
# No data available for Renault Scenic after filtering for car count.
# Processing Mazda 6
# No data available for Mazda 6 after filtering for car count.
# Processing Hyundai Matrix
# Depreciation data saved for Hyundai Matrix
# Processing Dacia Jogger
# Depreciation data saved for Dacia Jogger
# Processing Dacia Duster
# Depreciation data saved for Dacia Duster
# Processing Chevrolet Epica
# Depreciation data saved for Chevrolet Epica
# Processing Audi A8
# No data available for Audi A8 after filtering for car count.
# Processing Toyota Corona
# No data available for Toyota Corona after applying filters.
# Processing Citroen C2
# No data available for Citroen C2 after applying filters.
# Processing Jaguar X-Type
# No data available for Jaguar X-Type after applying filters.
# Processing Rover 216
# No data available for Rover 216 after applying filters.
# Processing MINI Cooper S
# No data available for MINI Cooper S after filtering for car count.
# Processing Kia Pride
# No data available for Kia Pride after applying filters.
# Processing Volkswagen Scirocco
# Depreciation data saved for Volkswagen Scirocco
# Processing Chevrolet Rezzo
# No data available for Chevrolet Rezzo after applying filters.
# Processing Alfa Romeo
# Depreciation data saved for Alfa Romeo
# Processing Audi
# Depreciation data saved for Audi
# Processing BMW
# Depreciation data saved for BMW
# Processing Chevrolet
# Depreciation data saved for Chevrolet
# Processing Citroen
# Depreciation data saved for Citroen
# Processing Dacia
# Depreciation data saved for Dacia
# Processing Fiat
# Depreciation data saved for Fiat
# Processing Ford
# Depreciation data saved for Ford
# Processing Honda
# Depreciation data saved for Honda
# Processing Hyundai
# Depreciation data saved for Hyundai
# Processing Jaguar
# Depreciation data saved for Jaguar
# Processing Kia
# Depreciation data saved for Kia
# Processing Lada
# No data available for Lada after filtering for car count.
# Processing MINI
# /Users/soringrigoras/anaconda3/lib/python3.11/site-packages/statsmodels/nonparametric/smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),
# Depreciation data saved for MINI
# Processing Maserati
# No data available for Maserati after filtering for car count.
# Processing Mazda
# Depreciation data saved for Mazda
# Processing Mercedes
# Depreciation data saved for Mercedes
# Processing Mitsubishi
# Depreciation data saved for Mitsubishi
# Processing Nissan
# Depreciation data saved for Nissan
# Processing Opel
# Depreciation data saved for Opel
# Processing Peugeot
# Depreciation data saved for Peugeot
# Processing Porsche
# Depreciation data saved for Porsche
# Processing Renault
# Depreciation data saved for Renault
# Processing Rover
# No data available for Rover after applying filters.
# Processing Seat
# Depreciation data saved for Seat
# Processing Skoda
# Depreciation data saved for Skoda
# Processing Subaru
# No data available for Subaru after filtering for car count.
# Processing Suzuki
# Depreciation data saved for Suzuki
# Processing Tata
# Depreciation data saved for Tata
# Processing Tofaş
# No data available for Tofaş after applying filters.
# Processing Toyota
# Depreciation data saved for Toyota
# Processing Volkswagen
# Depreciation data saved for Volkswagen
# Processing Volvo
# Depreciation data saved for Volvo
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 156
#     153         continue
#     155 # Save the full depreciation data dictionary
# --> 156 joblib.dump(depreciation_data, "depreciation_data/depreciation_data_full.pkl")
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/numpy_pickle.py:552, in dump(value, filename, compress, protocol, cache_size)
#     550         NumpyPickler(f, protocol=protocol).dump(value)
#     551 elif is_filename:
# --> 552     with open(filename, 'wb') as f:
#     553         NumpyPickler(f, protocol=protocol).dump(value)
#     554 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'depreciation_data/depreciation_data_full.pkl'

# %%
# Define a more refined standard depreciation rate table

'''The logic of calculating the depreciated value involves using different levels of depreciation data, starting from the most specific (exact make and model) and falling back to more general data (model-level or standard depreciation table) if necessary. Here’s how it works:

	1.	Check for Exact Make-Model Depreciation Data:
	•	First, the function checks if there is depreciation data available for the exact make and model of the car.
	•	If data is available for the specific resell age (current age of the car plus the years kept), it uses this data directly.
	•	If data for the specific resell age is not available, it estimates the depreciation rate using the average annual depreciation of the make-model.
	2.	Fallback to Model-Level Depreciation Data:
	•	If the exact make-model depreciation data is not available, the function checks if there is general depreciation data available for the model.
	•	Similar to the make-model check, if data for the specific resell age is available, it uses this data.
	•	If data for the specific resell age is not available, it estimates the depreciation rate using the average annual depreciation of the model.
	3.	Fallback to Standard Depreciation Table:
	•	If neither make-model nor model-level depreciation data is available, the function uses a predefined standard depreciation table.
	•	This table defines different depreciation rates for different ranges of car ages:
	•	10% per year for the first two years.
	•	5% per year for the next seven years.
	•	3% per year for years beyond nine.

The function then applies the determined depreciation rate to the final price of the car to calculate the depreciated value.'''

standard_depreciation_rates = {
    'first_2_years': 0.10,
    'next_7_years': 0.05,
    'after_9_years': 0.03
}

# Function to calculate depreciated value using refined standard depreciation rates
def calculate_depreciated_value(car, final_price, resell_years, depreciation_data):
    make, model = car['Make'], car['Model']
    current_age = car['Car Age (Years)']
    resell_age = current_age + resell_years

    # Check for exact make and model depreciation data
    if (make, model) in depreciation_data:
        model_data = depreciation_data[(make, model)]
        if resell_age in model_data['Car Age (Years)'].values:
            depreciation_rate = model_data.loc[model_data['Car Age (Years)'] == resell_age, 'Percentage Loss'].values[0]
            method_used = "Exact Make-Model Depreciation Data"
        else:
            # Estimate using average annual depreciation
            avg_annual_depreciation = model_data['Percentage Loss'].mean()
            depreciation_rate = avg_annual_depreciation * resell_years
            method_used = "Estimated from Make-Model Average Depreciation"
    elif model in depreciation_data:
        model_data = depreciation_data[model]
        if resell_age in model_data['Car Age (Years)'].values:
            depreciation_rate = model_data.loc[model_data['Car Age (Years)'] == resell_age, 'Percentage Loss'].values[0]
            method_used = "Make-Level Depreciation Data"
        else:
            # Estimate using average annual depreciation
            avg_annual_depreciation = model_data['Percentage Loss'].mean()
            depreciation_rate = avg_annual_depreciation * resell_years
            method_used = "Estimated from Make-Level Average Depreciation"
    else:
        # Use refined standard depreciation rates
        depreciation_rate = 0
        if resell_age <= 2:
            depreciation_rate = standard_depreciation_rates['first_2_years'] * resell_age
        elif resell_age <= 9:
            depreciation_rate = (standard_depreciation_rates['first_2_years'] * 2) + (standard_depreciation_rates['next_7_years'] * (resell_age - 2))
        else:
            depreciation_rate = (standard_depreciation_rates['first_2_years'] * 2) + (standard_depreciation_rates['next_7_years'] * 7) + (standard_depreciation_rates['after_9_years'] * (resell_age - 9))
        method_used = "Standard Depreciation Table"

    depreciated_value = final_price * (1 - depreciation_rate / 100)
    return depreciated_value, method_used
